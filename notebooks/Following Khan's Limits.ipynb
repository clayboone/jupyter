# %%
def f(x):
    # lim(x -> -1) == -1
    return ((2*x + 1) / (x + 1) if x != -1 else -1)

for i in range(-1000, 1001):
    print(f(i))
# Out:
# 2.001001001001001
# 2.001002004008016
# 2.001003009027081
# 2.001004016064257
# 2.001005025125628
# 2.0010060362173037
# 2.001007049345418
# 2.001008064516129
# 2.0010090817356208
# 2.001010101010101
# 2.001011122345804
# 2.001012145748988
# 2.0010131712259374
# 2.0010141987829613
# 2.001015228426396
# 2.0010162601626016
# 2.0010172939979656
# 2.0010183299389004
# 2.001019367991845
# 2.0010204081632654
# 2.001021450459653
# 2.0010224948875255
# 2.0010235414534288
# 2.0010245901639343
# 2.001025641025641
# 2.0010266940451746
# 2.001027749229188
# 2.001028806584362
# 2.001029866117405
# 2.0010309278350515
# 2.001031991744066
# 2.00103305785124
# 2.001034126163392
# 2.0010351966873707
# 2.0010362694300516
# 2.0010373443983402
# 2.0010384215991692
# 2.001039501039501
# 2.001040582726327
# 2.0010416666666666
# 2.0010427528675705
# 2.001043841336117
# 2.001044932079415
# 2.0010460251046025
# 2.001047120418848
# 2.00104821802935
# 2.0010493179433366
# 2.0010504201680672
# ...

# %% [markdown]
# I'm having a hard time wrapping my brain around the math here. Shouldn't this be a parabola?
#
# Instead, as x -> -1, x = -1, but also as x -> ∞ *and* -∞, f(x) = 2. Why, tho?

# %%
import numpy as np

for i in np.arange(-2, 2, 0.001):
    x = round(i, 4)
    print(x, '\t', f(x))
# Out:
# -2.0 	 3.0
# -1.999 	 3.001001001
# -1.998 	 3.00200400802
# -1.997 	 3.00300902708
# -1.996 	 3.00401606426
# -1.995 	 3.00502512563
# -1.994 	 3.0060362173
# -1.993 	 3.00704934542
# -1.992 	 3.00806451613
# -1.991 	 3.00908173562
# -1.99 	 3.0101010101
# -1.989 	 3.0111223458
# -1.988 	 3.01214574899
# -1.987 	 3.01317122594
# -1.986 	 3.01419878296
# -1.985 	 3.0152284264
# -1.984 	 3.0162601626
# -1.983 	 3.01729399797
# -1.982 	 3.0183299389
# -1.981 	 3.01936799185
# -1.98 	 3.02040816327
# -1.979 	 3.02145045965
# -1.978 	 3.02249488753
# -1.977 	 3.02354145343
# -1.976 	 3.02459016393
# -1.975 	 3.02564102564
# -1.974 	 3.02669404517
# -1.973 	 3.02774922919
# -1.972 	 3.02880658436
# -1.971 	 3.0298661174
# -1.97 	 3.03092783505
# -1.969 	 3.03199174407
# -1.968 	 3.03305785124
# -1.967 	 3.03412616339
# -1.966 	 3.03519668737
# -1.965 	 3.03626943005
# -1.964 	 3.03734439834
# -1.963 	 3.03842159917
# -1.962 	 3.0395010395
# -1.961 	 3.04058272633
# -1.96 	 3.04166666667
# ...
